# %% [markdown]
# ## Managing Topics using Kafka CLI
#
# As part of this topic let us see how we can manage Kafka topics using command line.
# * List the topics in the Kafka cluster
# * Drop the topic, if it exists
# * Create the topic using login user prefix and then retail. We will create topic with partitions as 3 and replication factor as 2.
# * List the topics to verify whether it is successfully created or not.
# * Describe the topic to get the details related to partitions of the topic.
#
# We need to pass zookeeper details to manage topics using `kafka-topics.sh` command.

# %% [markdown]
# Here are the commands to validate these on single node cluster for your reference.
#
# * List the topics in the Kafka cluster

# %%
# %%sh
#
# /opt/kafka/bin/kafka-topics.sh --list \
#     --zookeeper localhost:2181
# Out:
# sh: 2: /opt/kafka/bin/kafka-topics.sh: not found
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-1-4e7fe4b92244> in <module>
# ----> 1 get_ipython().run_cell_magic('sh', '', '\n/opt/kafka/bin/kafka-topics.sh --list \\\n    --zookeeper localhost:2181\n')
#
# ~/.local/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2369             with self.builtin_trap:
#    2370                 args = (magic_arg_s, cell)
# -> 2371                 result = fn(*args, **kwargs)
#    2372             return result
#    2373
#
# ~/.local/lib/python3.6/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# ~/.local/lib/python3.6/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/.local/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/.local/lib/python3.6/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'\n/opt/kafka/bin/kafka-topics.sh --list \\\n    --zookeeper localhost:2181\n'' returned non-zero exit status 127.

# %% [markdown]
# * Drop the topic, if it exists

# %%
# %%sh
#
# /opt/kafka/bin/kafka-topics.sh --delete \
#     --zookeeper locahost:2181 \
#     --topic `whoami`_retail

# %% [markdown]
# * Create the topic using login user prefix and then retail. We will create topic with partitions as 3 and replication factor as 2.

# %%
# %%sh
#
# /opt/kafka/bin/kafka-topics.sh --create \
#     --zookeeper localhost:2181 \
#     --replication-factor 1 \
#     --partitions 3 \
#     --topic `whoami`_retail

# %% [markdown]
# * List the topics to verify whether it is successfully created or not.

# %%
# %%sh
#
# /opt/kafka/bin/kafka-topics.sh --list \
#     --zookeeper localhost:2181 \
#     --topic `whoami`_retail

# %% [markdown]
# * Describe the topic to get the details related to partitions of the topic.

# %%
# %%sh
#
# /opt/kafka/bin/kafka-topics.sh --describe \
#     --zookeeper localhost:2181 \
#     --topic `whoami`_retail

# %% [markdown]
# Here are the commands to validate these on multi node cluster for your reference.
#
# * List the topics in the Kafka cluster

# %%
# %%sh
#
# /opt/kafka/bin/kafka-topics.sh --list \
#     --zookeeper m01.itversity.com:2181,m02.itversity.com:2181,w01.itversity.com:2181
# Out:
# --itv002540-kafka1
# --itv002540_kafka1
# 5
# Antu_retail
# Ashok_retail
# Chauchau_Assignment
# Cusdata
# Customers_topic_007
# Customers_topic_new_007
# DBDA
# Demo
# Dikwan
# Dion
# Eliana_Kafka_Assess
# Elliot_Assignment
# Elliot_Assignment_2
# Elliot_Final
# Food
# IndePromotion
# Kafka-Testing
# KafkaMohit
# KafkaTutorial
# Lipsa-customers-new
# Lipsa_Kafka_Topic1
# Mary
# MaryWanjiru
# Mbau
# McDonaldpromo
# Mcdonaldpromo
# Meerlearning
# Meerlearning1
# Meerlearning2
# Michael
# Mihlali_000732
# Mihlali_000732_assignment
# Mihlali_000732_assignment_2
# Muk
# Mukuka
# PYSPARK
# Poojaretail
# PosFanout-KSTREAM-AGGREGATE-STATE-STORE-0000000004-changelog
# PosFanout-KSTREAM-AGGREGATE-STATE-STORE-0000000004-repartition
# Q2_Thabiso
# Q2_Thabiso.
# Q2_Thabisop
# Ritesh
# Sep
# Sep19
# Sept19
# Shivaar_Data_Engineering_Final_Project
# Shivaar_Kafka_Assignment_Q1
# Shivaar_Kafka_Assignment_Q2
# TET
# Tema_ass
# Tema_flafka
# Tema_flaka
# Tema_kafka
# Temaf_flaka
# Tsau
# Tsau_Mbhau
# Tsaurai_Seatlane
# Tsauu
# Tshego
# Wire_other_consumer
# Wires_consumer
# Wires_consumer_error
# Wires_producer
# Yuvi_topic
# __consumer_offsets
# _retail
# abhishek
# ajaykafkademo
# akhilkafka
# akhilkafka_2
# akintraining
# all_order_ashna
# all_order_shashank
# all_order_shashank2
# all_orders
# all_orders_anvesh
# all_orders_ashna
# all_orders_topic
# all_orders_topic_007
# amar_topic
# amar_topic1
# amu
# angola19
# animals
# anutopic1
# app_events
# arc
# archana1
# aryan
# aryan_customer
# aryan_customers
# asa
# asa_de
# ashnatestnew
# ashnatestnew01
# assignment-itv003225
# authors
# aviksha_asiignmnetQ2
# aviksha_assignmentQ2
# b7kafka
# b7kafkha
# b99
# b_kafka
# baruch_question1
# baruch_question2
# bells_flaf
# bells_flafka
# bernard_1
# bernard_q1
# bernard_q2
# bernard_spark_assignment
# bhavkafka
# bonani
# brynne1
# brynne_q1
# brynne_q2
# cailin
# cailin1
# cars
# cctxn_sj
# cctxnitv003225
# cctxnstopicashnafaris
# cctxnstopicashnafariss
# cctxnstopicashnafariz
# cctxnstopicdeepa
# cctxnstopicdeepa1
# cctxnstopicdeepa2
# cctxnstopicdeepamagi
# cctxnstopicmandeep
# cdt_sep_19
# centos_demo
# cities-0
# clicks
# closed_orders
# closed_orders_ashna
# completed_orders
# completed_orders_ashna
# consumeg
# cust-new-3-part
# custo
# customer
# customer-itv003225
# customer-new
# customer10
# customerDip
# customerKalpi
# customer_Dip
# customer_itv
# customer_itv001067
# customer_itv002879
# customer_new_itv002879
# customerr
# customerrs
# customers
# customers-c1
# customers-c2
# customers-c3
# customers-new
# customers-new-itv003225
# customers-new173
# customers003168
# customers004915
# customers1
# customers_173
# customers_itv000808
# customers_itv0008081
# customersitv000808
# customersitv004041
# customersitv004556
# data
# dataweb
# davie1
# day3
# day6
# days3
# de_final_project
# deb_sonal
# deepavaliOffer
# deepvaliOffer
# demo
# demo_topic
# democlear
# demotopic
# dg_retail
# dhruvKafka
# dhruvkafka
# discount_CVS
# eliana_topic
# eliana_topic2
# elliot_lu
# employtopic
# esther2
# esther3
# esther4
# exceptionTopic
# exception_topic
# exl_abhinav
# exlaman
# exlarchana
# exlasif
# exlrajat
# exlspa
# exlthju
# exthju
# faris
# finalproj_brynne
# first_topic
# first_topics
# firsttopic_itv004556
# flafka_Q1tpp
# flafka_Q2tpp
# flafka_assignment
# foobar0
# foobar1
# foobar2
# foobar3
# foobar4
# foobar5
# foobar6
# foobar7
# foobar8
# foobar9
# food
# footy
# full_orders_ashna
# github_repos_topic.gh_database.gh_repos
# github_test_topic
# github_test_topic2
# github_test_topic2.gh_database.gh_repos
# github_test_topic21
# github_test_topic3
# github_test_topic3.gh_database.gh_repos
# gunjan_surolia_kafka_topic
# gvrk_testing
# gvrktesting
# happybday
# hello-world-__assignor-__leader
# hello_kafka
# hello_list
# hunegrBox
# hungerBox
# ikramtopic
# ikramtopic7
# ikramtopic9
# impressions
# incomemodeloutput
# infobatch4
# itv000124_logs
# itv000457_demo
# itv000457_demo_topic
# itv000457_retail
# itv000558_demo
# itv000558_retail
# itv000558_retail_orders
# itv000676_demo
# itv000676_retail
# itv000676_retail_json
# itv000925_retail
# itv001044_Customers
# itv001044_Customers_New
# itv001044_First
# itv001044_NewFirst
# itv001204
# itv001368__retail
# itv001368_demo
# itv001368_retail
# itv001401_retail
# itv001425_retail
# itv001426_demo
# itv001426_retail
# itv001453_demo
# itv001453_retail
# itv001494_reeeeetail
# itv001505_demo
# itv001505_retail
# itv001536_1
# itv001550_demo
# itv001550_retail
# itv001556_demo
# itv001556_retail
# itv001600_customers
# itv001619_demo
# itv001619_retail
# itv001626_retail
# itv001693.demo
# itv001693_demo1
# itv001693_retail
# itv001715_demo
# itv001715_retail
# itv001734_retail
# itv001748_retail
# itv001773_demo
# itv001773_retail
# itv001779_demo
# itv001779_retail
# itv001794_demo
# itv001794_retail
# itv001810_retail
# itv001818-retail
# itv001818_demo
# itv001818_retail
# itv001983_retail
# itv002006_demo
# itv002006_retail
# itv002100
# itv002100_demo
# itv002100_memo
# itv002100_retail
# itv002144_retail
# itv002203
# itv002218topic
# itv002351_demo
# itv002351_retail
# itv002427_retail
# itv002455_demo
# itv002455_retail
# itv002540_kafka1
# itv002581topic
# itv002614
# itv003138_demo
# itv003138_demo2
# itv003138_retail
# itv003186_cust1
# itv003186_cust2
# itv003186_cust_new
# itv003186_customers
# itv003186_customers1
# itv003186_customers2
# itv003186_test
# itv003186_topic1
# itv003238_demo
# itv003238_retail
# itv003346_topic1
# itv003406_demo
# itv003406_retail
# itv003882_demo
# itv003882_retail
# itv003998_customers
# itv003998_customers_new
# itv003998_topic1
# itv003998_topic2
# itv004436
# itv004448
# itv004452aliyu
# itv004522
# itv004563_retail
# itv00457_retail
# itv004604_retail
# itv004635_demo
# itv004635_demo1
# itv004635_retail
# itv004635_test
# itv004635_test1
# itv004648_retail
# itv004683_demo
# itv004683_retail_new
# itv004727_demo
# itv004727_retail
# itv004BBB
# itv005002_demo
# itv005002_retail
# itv005004_demo
# itv005004_retail
# itv005087_retail_nsd
# itv005332_demo
# itv005332_retail
# itv005372_demo
# itv005372_retail
# itv005379_demo
# itv005379_retail
# itv005438_demo
# itv005438_retail
# itv005441_cctxnstopicashnafaris
# itv005441_cctxnstopicashnafaris_new
# itv005511_demo
# itv005511_retail
# itv005529_retail
# itv005561_demo
# itv005561_retail
# itv005807_demo
# itv005807_retail
# itv006756_demo
# itv006756_retail
# itv007299_demo
# itv007299_retail
# itv007300_retail
# itv007300_retail_Seattle
# itv007304_demo
# itv007304_retail
# itv_demo
# itversity_demo
# itversity_retail
# itversity_retail_agg
# itversity_retail_json
# itvswapnil_w17q2
# itvswapnil_w17q3
# ivy_de
# ivy_manoj
# ivy_pt
# ivy_yojakta
# ivydecode
# jabra
# jack_sep_19
# jack_sep_19A
# jafs
# jafs_topic1
# jarcheckitv003225
# jarcheckitv003225-allorders
# jarcheckitv003225-closedorders
# jarcheckitv003225-completeorders
# javaguides
# jay__retail
# jay_retail
# josenara
# jzn_topic
# kabiito
# kafakam
# kafdemo
# kafka1
# kafka101
# kafka2
# kafka392_demo
# kafkaDheeraj
# kafkaLB
# kafkaMohit
# kafkaPython
# kafkaSummer
# kafka_bl
# kafka_demo_feb07
# kafka_itv002469
# kafka_practice
# kafka_practice_comma
# kafka_topics
# kafka_topics-test
# kafka_twitter
# kafkaa1
# kafkaadg
# kafkaag
# kafkaam
# kafkade01
# kafkademo1
# kafkademodg
# kafkademopk
# kafkadfg
# kafkadg
# kafkadg1
# kafkadg12
# kafkadg13
# kafkadg4145
# kafkadg41456
# kafkadg99
# kafkahlony
# kafkahv
# kafkaitv1
# kafkakevin
# kafkam
# kafkamanoj
# kafkamic
# kafkamitra
# kafkamohit
# kafkamorare
# kafkams
# kafkamuku
# kafkandricim
# kafkapart
# kafkapratik
# kafkaraghu
# kafkaraghuBalagadde
# kafkasanket
# kafkatest
# kafkatest_sr
# kafkatopic
# kafkatopic1
# kafkatopic2
# kafkatwitter
# kafkaty
# kafkavarun
# kafkevin
# kafkhv
# kafute
# kaka
# kancharla_demo
# kancharla_retail
# kancharla_retails
# kerry27324
# kfcspecialprmo
# kgtopic
# khalid_customers
# khalid_kafka
# khalidtopic
# kjafkaraghu
# kptest
# kptest1
# ktuk_retail
# labour_day_promo
# lawrence_kafka_assignment_q2
# lehela
# login-json
# logstokafka
# logstokakfa
# madhu_kafka
# maggie_kafka_assignment_q1
# maggie_kafka_assignment_q2
# magnus
# marijuana
# marquard
# mathapelo
# meetuprsvptopic
# meetuprsvptopic1
# meetuprsvtopic
# meetuprsvtopic1
# meghcustomers
# mic
# mihlali_000732
# mihlali_000732_assignment
# mihlali_000732_assignment_2
# mnc_list1
# mnc_list3
# mnc_topic1
# mnc_topic2
# mnc_topic3
# months
# morris_demo
# msdtest
# my-first-topic
# my-sundeep_reviews
# my-topic
# myKafka
# myTopic
# myTopic1
# myTopic2
# my_topic
# myfirst
# myfirst-b7
# myfirst_b7
# mykafkatopic1itv004041
# mykafkatopicitv004041
# mykakfatopic
# mynewsha
# mynewtopic
# mynewtopic004915
# mynewtopic1
# mynewtopic111
# mynewtopic12
# mynewtopic173
# mynewtopic2
# mynewtopic2023
# mynewtopic222
# mynewtopicmegha
# mynewtopicmegha33
# mynewtopicmegha34
# mytopic
# mytopic125
# mytopic2
# mytopic555
# mytopic77
# mytopic78
# mytopic79
# mytopic80
# nalangcobo
# names
# new_topic
# new_topiic
# newheight
# newtop
# newtop--from-beginning
# newtopic
# newtopicitv004556
# nikhila_input
# order_itv002879
# oreder
# ournewtopic
# ournewtopic004915
# ourtopic
# parent
# perf
# persondetails_consumer
# persondetails_producer
# persondts_topic3
# poc_retail_db
# pranit_kafka
# prashant
# pyspark
# pyspark-kafka-demo
# qazwsx
# qhrack
# rajeevranjan_demo
# rawTestData
# real_time_project
# redbull
# retai_itv004937
# retaiitv004937
# retail
# retail-topic
# retail-topics
# retail12345
# retail1785
# retail785
# retailDip
# retail_001
# retail_006
# retail_987
# retail_Dip
# retail_db
# retail_db_balusai1
# retail_demo
# retail_demo111
# retail_gen_logs
# retail_itv00004937
# retail_itv000808
# retail_itv000808_2
# retail_itv000xxx
# retail_itv003186
# retail_multi
# retail_multi_part
# retail_multi_sbi
# retail_sb
# retail_sbi
# retail_single
# retail_t
# retail_topic_1
# retails-topics
# rj93
# rod_assessement
# rod_test
# rod_test2
# rodrigues
# ruby_1
# ruby_12
# sales
# sample
# samtest
# sandro
# sanjit_appollo_test
# sbanerjee1
# sbi_kafka
# sbnewtopic1
# sbnewtopicc10
# sbsa_LAWRENCE1
# sbsa_Michael
# sbsa_arc1
# sbsa_baruch
# sbsa_baruch1
# sbsa_bernard
# sbsa_bl
# sbsa_eb1
# sbsa_eb2
# sbsa_el
# sbsa_ell
# sbsa_ellybe
# sbsa_emm
# sbsa_fk
# sbsa_joy
# sbsa_joy1
# sbsa_joy2
# sbsa_joyassignment
# sbsa_joyassignment1
# sbsa_joyassignment2
# sbsa_joyassignment3
# sbsa_joyassignment4
# sbsa_joyassignmentq1
# sbsa_joyfinalproject
# sbsa_joyfinalprojecttest
# sbsa_mary
# sbsa_mat
# sbsa_mat--group
# sbsa_mat1
# sbsa_michael
# sbsa_mihlali
# sbsa_mihlali1
# sbsa_mkhuleko
# sbsa_mkhuleko_assign1
# sbsa_mkhuleko_assign2
# sbsa_mkhuleko_project
# sbsa_mkhuleko_project_output
# sbsa_mukuka
# sbsa_ndumiso_nhlozi
# sbsa_rodrigues
# sbsa_rodrigues1
# sbsa_ss_topic
# sbsa_stephen
# sbsa_tet
# sbsa_tet1
# sbsa_tpp
# sbsa_tsau
# sbsa_tsaurai
# sbsa_vr
# sbsa_xol
# sbsa_xol1
# sbsa_xol_kfk
# sbsa_xxx
# sbsastephen
# scalaFirstTopic
# section7
# section7_v1
# sep19
# session_kafka
# shashank1
# shavy_topic
# sid
# siva_kafka_1
# skmulfactor
# sktest
# sktopic2partition
# slogin-jsjson
# som_test
# soup
# spark_Rod
# spark_kafka
# spark_kafka_xol
# spark_output_mihlali
# spark_rodrigues
# srikafka01
# srikafka02
# srikanttest1
# srm
# ss_topic_1
# streams-plaintext-input
# streams-wordcount-output
# study_itv0010167
# study_itv001067
# suman_kafka
# sundeep_reviews
# surojit_first_topic
# tdsktest
# te
# teest
# temitope
# tempitv003225
# tempitv003225-2
# tempitv003225_1
# tempitv003225new
# test
# test-01
# test123
# test1_topic
# test_retail
# test_sikha
# test_single_part
# test_topic1
# test_xol
# testarc
# testkafka
# testkartheek
# testr
# testrc
# thabisop_assignment
# threading_new
# topic
# topic-t1
# topic1
# topic173
# topic_assignment
# topic_assignment2
# topic_file
# topic_for_gpkafka
# topic_haile
# topicc1
# treestance
# treestance3
# treestance_topic
# truesday
# tsau
# tsautsau
# tshego_assignment
# tshego_q1
# tshego_q2
# tst_topic_practice_01
# tuesday
# tweet
# twitter
# user-details
# user_itv003783
# vcustomers
# vcustomers-new
# vecna
# vhamu738
# vhamu_DE_Proj
# vhamu_kafka1
# vhamu_kafka2
# vibstopic
# vikram_movie_promo
# vita
# vita1
# vita1--from-beginning
# vita254
# vita2541
# vita8596
# vj_cctxnstopicashnafaris
# w17q1
# web_1
# web_log1
# weblogs
# weblogs2
# weblogs_2
# whoami.demo
# whoami_jay__retail
# wiki-changes
# xol2_flafka_assignment
# xol_flafka_assignment
# yateschat

# %%
# !whoami
# Out:
# itv007304

# %% [markdown]
# * Drop the topic, if it exists

# %%
# %%sh
#
# /opt/kafka/bin/kafka-topics.sh --delete \
#     --zookeeper m01.itversity.com:2181,m02.itversity.com:2181,w01.itversity.com:2181 \
#     --topic `whoami`_retail

# %% [markdown]
# * Create the topic using login user prefix and then retail. We will create topic with partitions as 3 and replication factor as 2.

# %%
# %%sh
#
# /opt/kafka/bin/kafka-topics.sh --create \
#     --zookeeper m01.itversity.com:2181,m02.itversity.com:2181,w01.itversity.com:2181 \
#     --replication-factor 2 \
#     --partitions 3 \
#     --topic `whoami`_retail
# Out:
# WARNING: Due to limitations in metric names, topics with a period ('.') or underscore ('_') could collide. To avoid issues it is best to use either, but not both.
# Created topic itv007304_retail.

# %% [markdown]
# * List the topics to verify whether it is successfully created or not.

# %%
# %%sh
#
# /opt/kafka/bin/kafka-topics.sh --list \
#     --zookeeper m01.itversity.com:2181,m02.itversity.com:2181,w01.itversity.com:2181 \
#     --topic `whoami`_retail
# Out:
# itv007304_retail

# %% [markdown]
# * Describe the topic to get the details related to partitions of the topic.

# %%
# %%sh
#
# /opt/kafka/bin/kafka-topics.sh --describe \
#     --zookeeper m01.itversity.com:2181,m02.itversity.com:2181,w01.itversity.com:2181 \
#     --topic `whoami`_retail
# Out:
# Topic: itv007304_retail	PartitionCount: 3	ReplicationFactor: 2	Configs:
# 	Topic: itv007304_retail	Partition: 0	Leader: 3	Replicas: 3,1	Isr: 3,1
# 	Topic: itv007304_retail	Partition: 1	Leader: 1	Replicas: 1,2	Isr: 1,2
# 	Topic: itv007304_retail	Partition: 2	Leader: 2	Replicas: 2,3	Isr: 2,3
